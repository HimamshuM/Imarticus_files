# %%
# pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
from pytesseract import pytesseract
import pytesseract
import matplotlib.pyplot as plt

# %%
# path_to_esseract = r"D:\[ Learning ] _ DataScience\Imarticus\7_Neural_Network\OpenCV\tesseract-ocr-w64-setup-5.4.0.20240606.exe"

# %%
img = Image.open(r"D:\[ Learning ] _ DataScience\Imarticus\7_Neural_Network\OpenCV\Image20241006163027.jpg")
img1 = img.convert("L")
plt.imshow(img1)

# %%
pytesseract.pytesseract.tesseract_cmd = r"D:\[ Learning ] _ DataScience\Imarticus\7_Neural_Network\OpenCV\tesseract\tessdata"

print(pytesseract.image_to_string(img1))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18800\3222654845.py in <module>
#       1 pytesseract.pytesseract.tesseract_cmd = r"D:\[ Learning ] _ DataScience\Imarticus\7_Neural_Network\OpenCV\tesseract\tessdata"
#       2
# ----> 3 print(pytesseract.image_to_string(img1))
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in image_to_string(image, lang, config, nice, output_type, timeout)
#     484     args = [image, 'txt', lang, config, nice, timeout]
#     485
# --> 486     return {
#     487         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488         Output.DICT: lambda: {'text': run_and_get_output(*args)},
#
# ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py in <lambda>()
#     487         Output.BYTES: lambda: run_and_get_output(*(args + [True])),
# ...
