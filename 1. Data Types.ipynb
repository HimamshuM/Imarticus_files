# %%
print("Hello World")
# Out:
# Hello World

# %%
# integer Data Types 

x = 30
print(x)
print(type(x))
# Out:
# 30
# <class 'int'>

# %%
## float

x = 30.4
type(x)
# Out:
# float

# %%
## boolean

# True
#Flase

x = True
print(x)
type(x)
# Out:
# True
# bool

# %%
## sting

x = "Manasvi"
print(x)
print(type(x))

c = 'c'
print(type(c))
# Out:
# Manasvi
# <class 'str'>
# <class 'str'>

# %%
## How to take input 

x = str(input("Enter your name: "))
print("hello",end="\n")
print("Shembdi ",x)
# Out:
# Enter your name:  Manasvi
# hello
# Shembdi  Manasvi

# %%
a = 20 
b = 40 

print(a + b)
print(a*b)

print(b/a)  ## will give ans in float 
print(b//a) ## will only give int value
print(b % a,"see result",55%3) ## will give  remainder
# Out:
# 60
# 800
# 2.0
# 2
# 0 see result 1

# %%
print("Hello" + "Go" )## Concatination

print("Hello" + str(5)) ## type casting
# Out:
# HelloGo
# Hello5

# %%
## If else program
age=10
if age>=18:
    print("Your are eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Not eligible for voting

# %%
## elif to check multiple condition

age=50
if age<=10:
    print("Your child")
elif age>=10 and age<=25:
    print("your teenager")
else:
    print("your adult")
# Out:
# your adult

# %%
#Nested if else
num=int(input("Enter a number : "))
if num>0:
    print("Num is positive")
    if num%2==0:
        print("Number is even")
    else:
        print("Number is odd")
else:
    print("Number is zero or negative")
# Out:
# Enter a number :  11
# Num is positive
# Number is odd

# %%
## Program to write year is leap year or not

year=int(input("Enter the year : "))
if year%4==0:
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter the year :  20
# Leap year
