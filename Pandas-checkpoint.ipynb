# %%
import pandas as pd

# %% [markdown]
# - read the file
# - path
# - file name
# - format

# %%
pd.read_csv("bodyfat.csv")
# Out:
#     Bodyfat  Age  Weight  Height  Neck  Chest  Abdomen  Ankle  Biceps  Wrist
# 0      32.3   41  247.25   73.50  42.1  117.0    115.6   26.3    37.3   19.7
# 1      22.5   31  177.25   71.50  36.2  101.1     92.4   24.6    30.1   18.2
# 2      22.0   42  156.25   69.00  35.5   97.8     86.0   24.0    31.2   17.4
# 3      12.3   23  154.25   67.75  36.2   93.1     85.2   21.9    32.0   17.1
# 4      20.5   46  177.00   70.00  37.2   99.7     95.6   22.5    29.1   17.7
# ..      ...  ...     ...     ...   ...    ...      ...    ...     ...    ...
# 95     20.1   48  177.25   72.75  36.8   96.0     90.0   22.8    29.9   18.1
# 96     29.4   43  187.75   74.00  37.7   97.8     98.6   23.8    34.3   17.7
# 97     13.0   33  184.25   68.75  40.7   98.9     92.1   23.5    33.5   19.7
# 98     25.2   26  223.00   70.25  40.6  114.1    106.8   24.7    36.0   18.4
# 99      4.0   47  127.50   66.75  34.0   83.4     70.4   21.9    26.8   16.8
#
# [100 rows x 10 columns]

# %%
pd.read_csv("CreditRisk.csv")
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed
# 0    LP001002   Male      No         0.0      Graduate            No  \
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
cr = pd.read_csv("CreditRisk.csv")

# %%
cr
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed
# 0    LP001002   Male      No         0.0      Graduate            No  \
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
# print(type(cr)) # to check type of our veriable
# print(cr.shape)
# print(cr.values)
# # print(cr.columns)
# print(cr.astype)
print(cr.describe)
# Out:
# <bound method NDFrame.describe of       Loan_ID Gender Married  Dependents     Education Self_Employed
# 0    LP001002   Male      No         0.0      Graduate            No  \
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
cr.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ## Operations on dataframe

# %% [markdown]
# ### 1. Shape

# %%
cr.shape
# Out:
# (981, 13)

# %%
print(cr.shape[0])
print(cr.shape[1])
# Out:
# 981
# 13

# %% [markdown]
# ### 2. head

# %%
cr.head()  # It will show the first n records of dataframe
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed
# 0  LP001002   Male      No         0.0      Graduate            No  \
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 0             5849                0.0         NaN             360.0  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# ### Analysis on data-

# %%
# how to select perticular columns. 
print(cr.Married)
print(cr['Education'])
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 976    Yes
# 977    Yes
# 978     No
# 979    Yes
# 980     No
# Name: Married, Length: 981, dtype: object
# 0          Graduate
# 1          Graduate
# 2          Graduate
# 3      Not Graduate
# 4          Graduate
#            ...
# 976    Not Graduate
# 977        Graduate
# 978        Graduate
# 979        Graduate
# 980        Graduate
# Name: Education, Length: 981, dtype: object

# %%
print(cr['ApplicantIncome'].mean())
print(cr['ApplicantIncome'].median())
print(cr['ApplicantIncome'].mode())
print(cr['ApplicantIncome'].std())
print(cr['ApplicantIncome'].skew())
print(cr['ApplicantIncome'].min())
print(cr['ApplicantIncome'].max())
print(cr['ApplicantIncome'].var())
# Out:
# 5179.795107033639
# 3800.0
# 0    2500
# Name: ApplicantIncome, dtype: int64
# 5695.104532539108
# 7.086961153594506
# 0
# 81000
# 32434215.636547495

# %% [markdown]
# ### 3. Descibe
#
# -we can see whole info in one fuction called Described.

# %%
cr['ApplicantIncome'].describe()
# Out:
# count      981.000000
# mean      5179.795107
# std       5695.104533
# min          0.000000
# 25%       2875.000000
# 50%       3800.000000
# 75%       5516.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# ### Unique
# - how many unique values in columns

# %%
cr['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
# check the count of unique values
print(len(cr['Education'].unique()))

# OR
print(cr['Education'].nunique())  #nunique function
# Out:
# 2
# 2

# %%
cr['Education'].value_counts()
# Out:
# Education
# Graduate        763
# Not Graduate    218
# Name: count, dtype: int64

# %%
cr['Education'].count()
# Out:
# 981

# %%
cr.Property_Area.value_counts()
# Out:
# Property_Area
# Semiurban    349
# Urban        342
# Rural        290
# Name: count, dtype: int64

# %% [markdown]
# ### Que 1. Fetch the mean income of graduate and non graduate

# %%
cr.groupby('Education').ApplicantIncome.mean()
# Out:
# Education
# Graduate        5602.440367
# Not Graduate    3700.536697
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby('Self_Employed').ApplicantIncome.mean()
# Out:
# Self_Employed
# No     4892.030979
# Yes    6912.579832
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby('Gender').ApplicantIncome.median()
# Out:
# Gender
# Female    3634.5
# Male      3865.0
# Name: ApplicantIncome, dtype: float64

# %%
cr.groupby('Married').ApplicantIncome.mean().round(2)
# Out:
# Married
# No     4778.73
# Yes    5395.46
# Name: ApplicantIncome, dtype: float64

# %%
# incomes of graduate males vs non graduate males

cr.groupby(['Married','Gender','Education']).ApplicantIncome.mean().round(2)
# Out:
# Married  Gender  Education
# No       Female  Graduate        4424.72
#                  Not Graduate    4259.91
#          Male    Graduate        5268.52
#                  Not Graduate    3663.85
# Yes      Female  Graduate        4860.57
#                  Not Graduate    3001.18
#          Male    Graduate        5908.52
#                  Not Graduate    3706.70
# Name: ApplicantIncome, dtype: float64

# %%
cr
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed
# 0    LP001002   Male      No         0.0      Graduate            No  \
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
cr.groupby('Credit_History').Loan_Status.value_counts()
# Out:
# Credit_History  Loan_Status
# 0.0             N              140
#                 Y                8
# 1.0             Y              640
#                 N              114
# Name: count, dtype: int64

# %%
# Aim is to study relation b/w credit history and its impact on loan approval or rejection 
pd.crosstab(cr.Credit_History,cr.Loan_Status)
# Out:
# Loan_Status       N    Y
# Credit_History
# 0.0             140    8
# 1.0             114  640

# %%
(640 / 754)*100
# Out:
# 84.88063660477454

# %%
pd.crosstab(cr.Education,cr.Loan_Status)
# Out:
# Loan_Status     N    Y
# Education
# Graduate      196  567
# Not Graduate   73  145

# %% [markdown]
#  - In above table we can see that Loan approval of gradutes are high (567)

# %%
pd.crosstab(cr.Gender,cr.Loan_Status)
# Out:
# Loan_Status    N    Y
# Gender
# Female        55  127
# Male         207  568

# %%
#for Males :

568 /(207+568)
# Out:
# 0.7329032258064516

# %%
df = pd.read_csv('Mtcars.csv')

# %%
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
abcd = pd.read_clipboard() # Another way to read file.

# %%
abcd
# Out:
# Empty DataFrame
# Columns: [https://xhamster.com/tags/aznude]
# Index: []

# %%
# Aim : Impact of veriables on mpg

# %%
# finding corr between two columns

df.wt.corr(df.mpg)   # Range of correlation -1 to +1 ( Higher weight lower milage)
# Out:
# -0.8676593765172281

# %%
df.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684  \
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
df1 = pd.read_csv('bodyfat.csv')

# %%
df1
# Out:
#     Bodyfat  Age  Weight  Height  Neck  Chest  Abdomen  Ankle  Biceps  Wrist
# 0      32.3   41  247.25   73.50  42.1  117.0    115.6   26.3    37.3   19.7
# 1      22.5   31  177.25   71.50  36.2  101.1     92.4   24.6    30.1   18.2
# 2      22.0   42  156.25   69.00  35.5   97.8     86.0   24.0    31.2   17.4
# 3      12.3   23  154.25   67.75  36.2   93.1     85.2   21.9    32.0   17.1
# 4      20.5   46  177.00   70.00  37.2   99.7     95.6   22.5    29.1   17.7
# ..      ...  ...     ...     ...   ...    ...      ...    ...     ...    ...
# 95     20.1   48  177.25   72.75  36.8   96.0     90.0   22.8    29.9   18.1
# 96     29.4   43  187.75   74.00  37.7   97.8     98.6   23.8    34.3   17.7
# 97     13.0   33  184.25   68.75  40.7   98.9     92.1   23.5    33.5   19.7
# 98     25.2   26  223.00   70.25  40.6  114.1    106.8   24.7    36.0   18.4
# 99      4.0   47  127.50   66.75  34.0   83.4     70.4   21.9    26.8   16.8
#
# [100 rows x 10 columns]

# %%
df1.corr().min()
# Out:
# Bodyfat    0.032210
# Age       -0.268673
# Weight    -0.097905
# Height    -0.268673
# Neck       0.038501
# Chest      0.072908
# Abdomen    0.141339
# Ankle     -0.073522
# Biceps    -0.079398
# Wrist      0.216315
# dtype: float64

# %%
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
print(abcd[abcd.ApplicantIncome] > 5000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32404\2203306199.py in <module>
# ----> 1 print(abcd[abcd.ApplicantIncome] > 5000)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ApplicantIncome'

# %%
cr[cr['ApplicantIncome'] >5000]
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed
# 0    LP001002    Male      No         0.0      Graduate            No  \
# 4    LP001008    Male      No         0.0      Graduate            No
# 5    LP001011    Male     Yes         2.0      Graduate           Yes
# 9    LP001020    Male     Yes         1.0      Graduate            No
# 20   LP001043    Male     Yes         0.0  Not Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 967  LP002920    Male     Yes         0.0      Graduate            No
# 968  LP002921    Male     Yes         4.0  Not Graduate            No
# 969  LP002932    Male     Yes         4.0      Graduate            No
# 974  LP002965  Female     Yes         0.0      Graduate            No
# 980  LP002989    Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
cr1 = cr[cr.ApplicantIncome > 4000]

# %%
cr2 = cr1[cr1.Gender== 'Male']

# %%
cr2

# %%
cr3 = cr2[cr2.Education == 'Graduate']

# %%
cr3

# %%
cr[(cr.ApplicantIncome > 5000) & (cr.Gender == 'Male') & (cr.Education == 'Graduate')]

# %%
cr[(cr.Gender[100]) & (cr.ApplicantIncome[100]) & (cr.Education[100])]

# %%
cr.iloc[[0,99,199,299,399],[1,4,6]]

# %%
cr.iloc[[0,99,199,299,399], : ]

# %%
cr.iloc[ : ,[1,4,6]]

# %%
cr.iloc[ : , [-1,-2,-3]]

# %%
cr.loc[:,['Loan_ID','Gender','Loan_Status']]

# %%
df = pd.read_csv('CreditRisk.csv')

# %%
df
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed
# 0    LP001002   Male      No         0.0      Graduate            No  \
# 1    LP001003   Male     Yes         1.0      Graduate            No
# 2    LP001005   Male     Yes         0.0      Graduate           Yes
# 3    LP001006   Male     Yes         0.0  Not Graduate            No
# 4    LP001008   Male      No         0.0      Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# ...

# %%
### Steps Invove in model building 

1. Requirement Gathering / Understanding the  problem. 
2. data Gathering
3. Data

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# I Want to see only those columns which have nulls. 
df.isnull().sum()[df.isnull().sum()> 0]
# Out:
# Gender              24
# Married              3
# Dependents          25
# Self_Employed       55
# LoanAmount          27
# Loan_Amount_Term    20
# Credit_History      79
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df1.shape
# Out:
# (769, 13)

# %%
df.shape
# Out:
# (981, 13)

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_csv('CreditRisk.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed
# 0  LP001002   Male      No         0.0      Graduate            No  \
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 0             5849                0.0         NaN             360.0  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# ### Filling values in nulls.

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      775
# Female    182
# Name: count, dtype: int64

# %%
df.Gender = df.Gender.fillna('Male')
# Or
# df.Gender.fillna('Male', inplace = True)

# %% [markdown]
# #### innull()

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Married              3
# Dependents          25
# Self_Employed       55
# LoanAmount          27
# Loan_Amount_Term    20
# Credit_History      79
# dtype: int64

# %%
df.Married.value_counts()
# Out:
# Married
# Yes    631
# No     347
# Name: count, dtype: int64

# %%
df.Dependents.value_counts()
# Out:
# Dependents
# 0.0    545
# 1.0    160
# 2.0    160
# 4.0     90
# 3.0      1
# Name: count, dtype: int64

# %%
df.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     807
# Yes    119
# Name: count, dtype: int64

# %%
df.LoanAmount.median()
# Out:
# 126.0

# %%
df.Loan_Amount_Term.median()
# Out:
# 360.0

# %%
df.Credit_History.value_counts()
# Out:
# Credit_History
# 1.0    754
# 0.0    148
# Name: count, dtype: int64

# %% [markdown]
# #### fillna()

# %%
df.Married.fillna('Yes', inplace=True)
df.Dependents.fillna(0,inplace=True)
df.Self_Employed.fillna('No',inplace=True)
df.LoanAmount.fillna(df.LoanAmount.median(),inplace=True)
df.Loan_Amount_Term.fillna(df.Loan_Amount_Term.median(),inplace=True)
df.Credit_History.fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    object
#  1   Gender             981 non-null    object
#  2   Married            981 non-null    object
#  3   Dependents         981 non-null    float64
#  4   Education          981 non-null    object
#  5   Self_Employed      981 non-null    object
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         981 non-null    float64
#  9   Loan_Amount_Term   981 non-null    float64
#  10  Credit_History     981 non-null    float64
#  11  Property_Area      981 non-null    object
#  12  Loan_Status        981 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 99.8+ KB

# %% [markdown]
# - we will have to convert the objects into int

# %% [markdown]
# #### df.drop()   - Droping columns

# %%
df = df.drop(['Loan_ID'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             981 non-null    object
#  1   Married            981 non-null    object
#  2   Dependents         981 non-null    float64
#  3   Education          981 non-null    object
#  4   Self_Employed      981 non-null    object
#  5   ApplicantIncome    981 non-null    int64
#  6   CoapplicantIncome  981 non-null    float64
#  7   LoanAmount         981 non-null    float64
#  8   Loan_Amount_Term   981 non-null    float64
#  9   Credit_History     981 non-null    float64
#  10  Property_Area      981 non-null    object
#  11  Loan_Status        981 non-null    object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 92.1+ KB

# %% [markdown]
# #### select_dtypes(include = '')

# %%
df.select_dtypes(include='object')
# Out:
#     Gender Married     Education Self_Employed Property_Area Loan_Status
# 0     Male      No      Graduate            No         Urban           Y
# 1     Male     Yes      Graduate            No         Rural           N
# 2     Male     Yes      Graduate           Yes         Urban           Y
# 3     Male     Yes  Not Graduate            No         Urban           Y
# 4     Male      No      Graduate            No         Urban           Y
# ..     ...     ...           ...           ...           ...         ...
# 976   Male     Yes  Not Graduate           Yes         Urban           Y
# 977   Male     Yes      Graduate            No         Urban           Y
# 978   Male      No      Graduate            No     Semiurban           Y
# 979   Male     Yes      Graduate            No         Rural           N
# 980   Male      No      Graduate           Yes         Rural           Y
#
# [981 rows x 6 columns]

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area',
#        'Loan_Status'],
#       dtype='object')

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.Gender.replace({'Male' : 1, 'Female' : 0}, inplace=True)

# %%
df.Gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.Married.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.Married.replace({'Yes' : 1, 'No':  0}, inplace=True)

# %%
df.Married.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df.Education.replace({'Graduate' : 1, 'Not Graduate':  0}, inplace=True)

# %%
df.Education.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.Self_Employed.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.Self_Employed.replace({'Yes' : 1, 'No':  0}, inplace=True)

# %%
df.Self_Employed.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Property_Area.unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df.Property_Area.replace({'Urban' : 2,'Rural':1,'Semiurban':0 },inplace=True)

# %%
df.Property_Area.unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df.Loan_Status.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df.Loan_Status.replace({'Y':1, 'N':0},inplace=True)

# %%
df.Loan_Status.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome
# 0         1        0         0.0          1              0             5849  \
# 1         1        1         1.0          1              0             4583
# 2         1        1         0.0          1              1             3000
# 3         1        1         0.0          0              0             2583
# 4         1        0         0.0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 976       1        1         4.0          0              1             4009
# 977       1        1         0.0          1              0             4158
# 978       1        0         0.0          1              0             3250
# 979       1        1         0.0          1              0             5000
# 980       1        0         0.0          1              1             9200
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_df,test_df = train_test_split(df, test_size=.2)

# %%
train_df.shape
# Out:
# (784, 12)

# %%
train_df.head()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome
# 256       1        0         0.0          0              0             6045  \
# 207       1        0         0.0          0              0             3975
# 466       1        1         4.0          0              0             2947
# 860       1        1         2.0          1              1             5000
# 900       1        1         0.0          0              0             2157
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History
# 256                0.0       115.0             360.0             0.0  \
# 207             2531.0        55.0             360.0             1.0
# 466             1664.0        70.0             180.0             0.0
# 860             2166.0       150.0             360.0             1.0
# 900             2730.0       140.0             360.0             0.0
#
#      Property_Area  Loan_Status
# 256              1            0
# ...
